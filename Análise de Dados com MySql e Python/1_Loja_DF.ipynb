# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
folder = "C:/Users/sucod/OneDrive/Lenovo/Documentos/Sql/"

ran = 81

# %%
Colunas = ["LucroPercentual","depVendas Med","depCusto Med","depGanho Med","depLucro Med","depVendas Total","depLucro Total"]
Linhas  = list(range(10,ran))
df_departamento_medias = pd.DataFrame(columns = Colunas, index = Linhas)

df_departamento_medias["LucroPercentual"] = Linhas
depVendas_list = []
depCusto_list = []
depGanho_list = []
depLucro_list = []
depVendasTotal_list = []
depLucroTotal_list = []

for x in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(x))
    depVendas_list.append((df.describe()).iloc[1,2])
df_departamento_medias["depVendas Med"] = depVendas_list

for x in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(x))
    depCusto_list.append((df.describe()).iloc[1,3])
df_departamento_medias["depCusto Med"] = depCusto_list
    
for x in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(x))
    depGanho_list.append((df.describe()).iloc[1,4])
df_departamento_medias["depGanho Med"] = depGanho_list

for x in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(x))
    depLucro_list.append((df.describe()).iloc[1,5])
df_departamento_medias["depLucro Med"] = depLucro_list

for x in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(x))
    depVendasTotal_list.append(df["depVendas"].sum())
df_departamento_medias["depVendas Total"] = depVendasTotal_list

for x in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(x))
    depLucroTotal_list.append(df["depLucro"].sum())
df_departamento_medias["depLucro Total"] = depLucroTotal_list

#df_departamento_medias.to_csv(r"{}".format(folder)+"/df_departamento_medias.csv")
#df_departamento_medias

grid = sns.PairGrid(df_departamento_medias, 
                    y_vars=["depVendas Med","depCusto Med","depGanho Med","depLucro Med", "depVendas Total","depLucro Total"], 
                 x_vars=["LucroPercentual","depVendas Med", "depVendas Total"], height = 3)
grid.map(plt.scatter, s=50, edgecolor="white", color = ".3")
grid.map(sns.regplot, color=".3")

# %%
Colunas = ["LucroPercentual","depVendas Min","depCusto Min","depGanho Min","depLucro Min"]
Linhas  = list(range(10,ran))
df_departamento_minimos = pd.DataFrame(columns = Colunas, index = Linhas)

df_departamento_minimos["LucroPercentual"] = Linhas
depVendas_list = []
depCusto_list = []
depGanho_list = []
depLucro_list = []

for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depVendas_list.append((df.describe()).iloc[3,2])
df_departamento_minimos["depVendas Min"] = depVendas_list

for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depCusto_list.append((df.describe()).iloc[3,3])
df_departamento_minimos["depCusto Min"] = depCusto_list
    
for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depGanho_list.append((df.describe()).iloc[3,4])
df_departamento_minimos["depGanho Min"] = depGanho_list

for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depLucro_list.append((df.describe()).iloc[3,5])
df_departamento_minimos["depLucro Min"] = depLucro_list


#df_departamento_minimos

grid = sns.PairGrid(df_departamento_minimos, 
                    y_vars=["depVendas Min","depCusto Min","depGanho Min","depLucro Min"], 
                 x_vars=["LucroPercentual","depVendas Min"], height = 3)
grid.map(plt.scatter,s=50, edgecolor="white", color = 'blue')
grid.map(sns.regplot)

# %%
Colunas = ["LucroPercentual","depVendas Max","depCusto Max","depGanho Max","depLucro Max"]
Linhas  = list(range(10,ran))
df_departamento_maximos = pd.DataFrame(columns = Colunas, index = Linhas)

df_departamento_maximos["LucroPercentual"] = Linhas
depVendas_list = []
depCusto_list = []
depGanho_list = []
depLucro_list = []

for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depVendas_list.append((df.describe()).iloc[7,2])
df_departamento_maximos["depVendas Max"] = depVendas_list

for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depCusto_list.append((df.describe()).iloc[7,3])
df_departamento_maximos["depCusto Max"] = depCusto_list
    
for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depGanho_list.append((df.describe()).iloc[7,4])
df_departamento_maximos["depGanho Max"] = depGanho_list

for lucro in range(10,ran):
    df = pd.read_csv(r"{}".format(folder)+"/CSVLoja/departamento_{}.csv".format(lucro))
    depLucro_list.append((df.describe()).iloc[7,5])
df_departamento_maximos["depLucro Max"] = depLucro_list


#df_departamento_maximos

grid = sns.PairGrid(df_departamento_maximos, 
                    y_vars=["depVendas Max","depCusto Max","depGanho Max","depLucro Max"], 
                 x_vars=["LucroPercentual","depVendas Max"], height = 3)
grid.map(plt.scatter,s=50, edgecolor="white")
grid.map(sns.regplot, color = 'purple')

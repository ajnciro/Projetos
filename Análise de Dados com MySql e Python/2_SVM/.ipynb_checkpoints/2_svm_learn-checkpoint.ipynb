# %% [markdown]
# **A supervisão de aprendizagem da SVM a seguir diz respeito ao parâmetro alvo ser um produto (ou intersecção) do lucro final de um item pela quantidade de vendas do mesmo. Foi observado e será mostrado no notebook de plots que, mesmo que o alvo de lucro seja mantido, senão forem realizadas vendas suficientes, o montante não será suficientemente incrementado, pois o custo de aquisição ou reposição do estoque compensa os valores gerados.**

# %% [markdown]
# **Desta forma, foram novos dados de aprendizado (com a mesma random seed), porém com lucros percentuais que variam desde 0 até 390%. Ainda, a variável depedente de treinamento foi colocada como sendo simultanemente um lucro >5000 e número de vendas >500 por produto. Mais detalhes adiante:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline
folder = "C:/Users/sucod/OneDrive/Lenovo/Documentos/Sql/"

# %%
df = pd.DataFrame(columns = [], index = [])
df2 = pd.DataFrame(columns = [], index = [])

for percent in range (0,391,10):
    df_aux = pd.read_csv(r"{}".format(folder)+"/CSVLoja3/produto_{}.csv".format(percent))
    df_aux["lucroPercent"] = percent
    df = pd.concat([df, df_aux],ignore_index=True)

for percent in range (0,391,10):        
    
    df_aux = pd.read_csv(r"{}".format(folder)+"/CSVLoja3/aquisicao_{}.csv".format(percent))


    for ID in range (1,251):
        count = 0
        for prodID in df_aux["Produto_idProduto"]:
            if prodID == ID:
                count+=1
        if count == 0:
            nova_linha = {'Produto_idProduto':ID, 'Quantidade':0}
            df_aux = df_aux.append(nova_linha,ignore_index=True)

    df_aux = df_aux.groupby("Produto_idProduto").mean()
        
    df2 = pd.concat([df2, df_aux["Quantidade"]],ignore_index=True)
    
del df['Unnamed: 0']
del df['idProduto'] 
del df['prodEstoque']
del df['Departamento_idDepartamento']

df["aquiMed"] = df2.to_numpy()
df_produto = df

df_produto["isLucro"]=(df_produto["prodLucro"]>5000)&(df_produto["prodVendas"]>500)
df_produto.tail()
# Out:
#       prodValor  prodVendas  prodCusto  prodCustoAcum  prodGanhoAcum  \
# 9995     114.46          21      23.36         630.72        2403.66
# 9996      35.57         161       7.26        2003.76        5726.77
# 9997     134.06          16      27.36           0.00        2144.96
# 9998     234.32           7      47.82           0.00        1640.24
# 9999     112.16          37      22.89           0.00        4149.92
#
#       prodLucro  lucroPercent  aquiMed  isLucro
# 9995    1772.94           390     27.0    False
# 9996    3723.01           390    138.0    False
# 9997    2144.96           390      0.0    False
# 9998    1640.24           390      0.0    False
# 9999    4149.92           390      0.0    False

# %% [markdown]
# **Com isso, o númento de pontos que respeitos essas condições caiu de cerca de 50% nos dados de treinamento e teste para cerca de 10% do total:**

# %%
df_produto["isLucro"].sum()
# Out:
# 1065

# %% [markdown]
# **Representados em laranja, forte clusterização:**

# %%
sns.pairplot(df_produto,hue="isLucro")

# %% [markdown]
# **Fazendo o treinamento da SVM com tais dados, foram colocadas as seguintes variáveis independentes:**

# %%
X = df.drop(['isLucro','prodGanhoAcum','prodVendas','prodCustoAcum','prodValor','prodGanhoAcum','prodLucro'], axis = 1)
Y = df['isLucro']
X.head()
# Out:
#    prodCusto  lucroPercent     aquiMed
# 0      35.03             0   86.875000
# 1      37.48             0   94.625000
# 2      45.67             0  109.800000
# 3       4.06             0   83.333333
# 4      31.68             0   90.750000

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C':[0.1,1,10,100,1000],'gamma':[1,0.1,0.01,0.001,0.0001],'kernel':['rbf']}
grid = GridSearchCV(SVC(),param_grid,refit = True, verbose = 3)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.891, total=   2.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.891, total=   2.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.2s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.891, total=   2.4s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.891, total=   2.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# ...

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
model = SVC(C = 1000, gamma = 0.001, kernel = 'rbf')
model.fit(X_train, Y_train)
pred = model.predict(X_test)

print(classification_report(Y_test, pred))
print('\n')
print(confusion_matrix(Y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      2697
#         True       0.82      0.81      0.82       303
#
#     accuracy                           0.96      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.96      0.96      0.96      3000
#
#
#
# [[2644   53]
#  [  57  246]]

# %% [markdown]
# **A precisão para revelar verdadeiros negativos foi maior que a de positivos, portanto isto será utilizado como parâmentro de implementação da máquina na predição:**

# %%
def max_lucro_min_aq(varcusto):
    x = 390
    while x>1:
        aqui = 1
        while aqui<150:
            cond = model.predict(pd.DataFrame(data={'prodCusto': [varcusto], 'lucroPercent': [x], 'aquiMed': [aqui]}))[0]
            if cond!=False: #Foi utilizada a negação da condição Falsa em lugar da Verdadeira
                return [x,aqui]
                break
            aqui+=1
        x-=1
        if x == 1:
                return [1,1]

# %% [markdown]
# **Utilizando a negação da Falsa condição em lugar da Verdadeira, foi um construída uma função a qual, dado um custo de produto, retorna um par (lucro, aquisição adequada). Aquisição adequada será a melhor quantidade de reposição do estoque, na eventualidade de falta, que maximizará o lucro (ou minimizará o custo), e simultaneamente ao melhor lucro percentual para aquele valor, a fim de obter o mínimo vendido de 5000 dinheiros e 500 unidades**
